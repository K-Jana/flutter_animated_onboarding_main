# %%
import numpy as np
import pandas as pd 
import sklearn
import nltk
import glob

# %%
tutors_df = pd.read_csv("D:/Final Project - LearnEra/recommendation algorithm/tutors.csv")

# %%
tutors_df
# Out:
#        Unnamed: 0          name        badge rating  reviews_number  \
# 0               0     Adrian Y.  Super tutor      5            12.0
# 1               1        Sai M.  Super tutor    4.9            52.0
# 2               2     Nayana K.  Super tutor    4.6            12.0
# 3               3    Sergei Ia.          NaN    4.8            33.0
# 4               4     Marina S.  Super tutor    4.9            70.0
# ...           ...           ...          ...    ...             ...
# 21543         609     Hannah K.          NaN      5             3.0
# 21544         610         민겸 박.          NaN    New             NaN
# 21545         611  MIYEON 미연 K.          NaN    New             NaN
# 21546         612     Hyebin K.          NaN    New             NaN
# 21547         613    Sun Hee J.          NaN    New             NaN
#
#        usd_price language  active_students  lessons_number  \
# 0             15  English              9.0          2652.0
# ...

# %%
tutors_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21548 entries, 0 to 21547
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       21548 non-null  int64
#  1   name             21548 non-null  object
#  2   badge            5749 non-null   object
#  3   rating           21548 non-null  object
#  4   reviews_number   15075 non-null  float64
#  5   usd_price        21548 non-null  int64
#  6   language         21548 non-null  object
#  7   active_students  18071 non-null  float64
#  8   lessons_number   15795 non-null  float64
#  9   speak            21548 non-null  object
#  10  description      21548 non-null  object
#  11  link             21548 non-null  object
#  12  Unnamed: 12      5 non-null      object
#  13  Unnamed: 13      3 non-null      object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
tutors_df = tutors_df[['name','language','speak','description']]

# %%
tutors_df
# Out:
#                name language                                        speak  \
# 0         Adrian Y.  English      English (Native), Portuguese (Advanced)
# 1            Sai M.  English          English (Native), Korean (Beginner)
# 2         Nayana K.  English  English (Native), Portuguese (Intermediate)
# 3        Sergei Ia.  English       English (Proficient), Russian (Native)
# 4         Marina S.  English                         English (Proficient)
# ...             ...      ...                                          ...
# 21543     Hannah K.   Korean        Korean (Native), English (Proficient)
# 21544         민겸 박.   Korean          Korean (Native), English (Advanced)
# 21545  MIYEON 미연 K.   Korean      Korean (Native), English (Intermediate)
# 21546     Hyebin K.   Korean          Korean (Native), English (Advanced)
# 21547    Sun Hee J.   Korean                              Korean (Native)
#
#                                              description
# ...

# %%
tutors_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21548 entries, 0 to 21547
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         21548 non-null  object
#  1   language     21548 non-null  object
#  2   speak        21548 non-null  object
#  3   description  21548 non-null  object
# dtypes: object(4)
# memory usage: 673.5+ KB

# %%
tutors_df.isnull().sum()
# Out:
# name           0
# language       0
# speak          0
# description    0
# dtype: int64

# %%
tutors_df.dropna(inplace = True)
# Out:
# C:\Users\janar\AppData\Local\Temp\ipykernel_11000\447736016.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tutors_df.dropna(inplace = True)
